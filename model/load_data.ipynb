# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import random

# %% [markdown]
# ### Tutorial Note: Loading in your own data by sentdex on YouTube
#
# Link: https://www.youtube.com/watch?v=j-3vuBynnOE&t=198s

# %%
datadir = "your directory here"
categories = ["BG","D","N","P","S","V"]

for category in categories:
    path = os.path.join(datadir, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(img_array, cmap = "gray")
        plt.show()
        break
    break

# %%
print(img_array.shape)
# Out:
# (211, 107, 3)

# %%
img_size = 50

new_array = cv2.resize(img_array, (img_size,img_size))
plt.imshow(new_array, cmap = 'gray')
plt.show()

# %% [markdown]
# ### Loading wound images and make its dataset
#
# Features: RBG values, 3-dimension
#
# Label: BG, D, N, P, S, V
#
# Total image: 738

# %%
wound_data = []

def create_data():
    for category in categories:
        path = os.path.join(datadir, category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try: 
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (img_size,img_size))
                wound_data.append([new_array, class_num])
            except EXCEPTION as e:
                pass
            
create_data()

# %%
print(len(training_data))
# Out:
# 738

# %%
random.shuffle(training_data)

# %%
X = []
Y = []

for features, label in wound_data:
    X.append(features)
    Y.append(label)
    
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 3)

# %%
X.shape
# Out:
# (738, 50, 50, 3)

# %%
len(Y)
# Out:
# 738

# %%
np.save("wound_features.npy", X)

# %%
np.save("wound_label.npy", Y)
